# %% [markdown]
# Read the data file

# %%
import pandas as pd
import numpy  as np

# %%
data = pd.read_csv('D:/GREAT LAKES/CAPSTONE/hypothyroid.csv')

# %%
print(data.shape)
# Out:
# (3772, 30)

# %% [markdown]
# ### Observations
#
# There are 3772 observations and 30 columns for our dataset.

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3772 entries, 0 to 3771
# Data columns (total 30 columns):
# age                          3772 non-null object
# sex                          3772 non-null object
# on thyroxine                 3772 non-null object
# query on thyroxine           3772 non-null object
# on antithyroid medication    3772 non-null object
# sick                         3772 non-null object
# pregnant                     3772 non-null object
# thyroid surgery              3772 non-null object
# I131 treatment               3772 non-null object
# query hypothyroid            3772 non-null object
# query hyperthyroid           3772 non-null object
# lithium                      3772 non-null object
# goitre                       3772 non-null object
# tumor                        3772 non-null object
# hypopituitary                3772 non-null object
# psych                        3772 non-null object
# TSH measured                 3772 non-null object
# ...

# %%
print(data.head(4).T)
# Out:
#                               0      1      2      3
# age                          41     23     46     70
# sex                           F      F      M      F
# on thyroxine                  f      f      f      t
# query on thyroxine            f      f      f      f
# on antithyroid medication     f      f      f      f
# sick                          f      f      f      f
# pregnant                      f      f      f      f
# thyroid surgery               f      f      f      f
# I131 treatment                f      f      f      f
# query hypothyroid             f      f      f      f
# query hyperthyroid            f      f      f      f
# lithium                       f      f      f      f
# goitre                        f      f      f      f
# tumor                         f      f      f      f
# hypopituitary                 f      f      f      f
# psych                         f      f      f      f
# TSH measured                  t      t      t      t
# ...

# %% [markdown]
# There are missing values denoted by ?. We need to replace them with null.

# %%
df = data.replace('?', np.NaN)
print(df.head(4).T)
# Out:
#                               0      1      2      3
# age                          41     23     46     70
# sex                           F      F      M      F
# on thyroxine                  f      f      f      t
# query on thyroxine            f      f      f      f
# on antithyroid medication     f      f      f      f
# sick                          f      f      f      f
# pregnant                      f      f      f      f
# thyroid surgery               f      f      f      f
# I131 treatment                f      f      f      f
# query hypothyroid             f      f      f      f
# query hyperthyroid            f      f      f      f
# lithium                       f      f      f      f
# goitre                        f      f      f      f
# tumor                         f      f      f      f
# hypopituitary                 f      f      f      f
# psych                         f      f      f      f
# TSH measured                  t      t      t      t
# ...

# %%
all_columns         = list(df)
numeric_columns     = ['age', 'TSH', 'T3', 'TT4', 'T4U', 'FTI']
categorical_columns = [x for x in all_columns if x not in numeric_columns ]

print('\nNumeric columns')
print(numeric_columns)
print('\nCategorical columns')
print(categorical_columns)
# Out:
# Numeric columns
# ['age', 'TSH', 'T3', 'TT4', 'T4U', 'FTI']
#
# Categorical columns
# ['sex', 'on thyroxine', 'query on thyroxine', 'on antithyroid medication', 'sick', 'pregnant', 'thyroid surgery', 'I131 treatment', 'query hypothyroid', 'query hyperthyroid', 'lithium', 'goitre', 'tumor', 'hypopituitary', 'psych', 'TSH measured', 'T3 measured', 'TT4 measured', 'T4U measured', 'FTI measured', 'TBG measured', 'TBG', 'referral source', 'binaryClass']

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3772 entries, 0 to 3771
# Data columns (total 30 columns):
# age                          3771 non-null object
# sex                          3622 non-null object
# on thyroxine                 3772 non-null object
# query on thyroxine           3772 non-null object
# on antithyroid medication    3772 non-null object
# sick                         3772 non-null object
# pregnant                     3772 non-null object
# thyroid surgery              3772 non-null object
# I131 treatment               3772 non-null object
# query hypothyroid            3772 non-null object
# query hyperthyroid           3772 non-null object
# lithium                      3772 non-null object
# goitre                       3772 non-null object
# tumor                        3772 non-null object
# hypopituitary                3772 non-null object
# psych                        3772 non-null object
# TSH measured                 3772 non-null object
# ...

# %% [markdown]
# Get column-wise count of missing values along with %.

# %%
df.isnull().apply(lambda x : [ sum(x), (sum(x) * 100) / df.shape[0]] )
# Out:
# age                          [1, 0.026511134676564158]
# sex                          [150, 3.9766702014846236]
# on thyroxine                                  [0, 0.0]
# query on thyroxine                            [0, 0.0]
# on antithyroid medication                     [0, 0.0]
# sick                                          [0, 0.0]
# pregnant                                      [0, 0.0]
# thyroid surgery                               [0, 0.0]
# I131 treatment                                [0, 0.0]
# query hypothyroid                             [0, 0.0]
# query hyperthyroid                            [0, 0.0]
# lithium                                       [0, 0.0]
# goitre                                        [0, 0.0]
# tumor                                         [0, 0.0]
# hypopituitary                                 [0, 0.0]
# psych                                         [0, 0.0]
# TSH measured                                  [0, 0.0]
# ...

# %% [markdown]
# ### Observation
#
# | # | Column | [ count, %] |
# | -- | ------------ | ---------------------- |
# | 1 |  age | [1, 0.026511134676564158] |
# | 2 |  sex  | [150, 3.9766702014846236] |
# | 3 |  TSH | [369, 9.782608695652174] |
# | 4 | T3 | [769, 20.387062566277837] |
# | 5 | TT4 | [231, 6.1240721102863205] |
# | 6 | T4U | [387, 10.25980911983033] |
# | 7 | FTI | [385, 10.2067868504772] |
# | 8 | TBG | [3772, 100.0] |

# %% [markdown]
# ### Observations
#
# Except the column, TBG, all other seven columns have percentage of missing values less than 30 %.
# The column, TBG is having 100% missing values.
# We shall drop the column, TBG and remove the missing values row-wise.

# %%
df.drop(columns = 'TBG', axis = 0, inplace = True)
df.dropna(axis = 0, inplace = True)

# %%
df['age'] = df['age'].astype('int32')
df['TSH'] = df['TSH'].astype('float64')
df['T3']  = df['T3'].astype('float64')
df['TT4'] = df['TT4'].astype('float64')
df['T4U'] = df['T4U'].astype('float64')
df['FTI'] = df['FTI'].astype('float64')

# %%
categorical_columns = ['sex', 'on thyroxine', 'query on thyroxine', 'on antithyroid medication', 'sick', \
                        'pregnant', 'thyroid surgery', 'I131 treatment', 'query hypothyroid', 'query hyperthyroid', \
                        'lithium', 'goitre', 'tumor', 'hypopituitary', 'psych', 'TSH measured',\
                        'T3 measured', 'TT4 measured', 'T4U measured', 'FTI measured', 'TBG measured',\
                        'referral source', 'binaryClass']
for name1 in categorical_columns:
    print("\nColumn: ", name1,"\n")
    print(df[name1].value_counts())
# Out:
# Column:  sex
#
# F    1764
# M     879
# Name: sex, dtype: int64
#
# Column:  on thyroxine
#
# f    2377
# t     266
# Name: on thyroxine, dtype: int64
#
# Column:  query on thyroxine
#
# f    2619
# t      24
# Name: query on thyroxine, dtype: int64
#
# Column:  on antithyroid medication
#
# f    2610
# t      33
# Name: on antithyroid medication, dtype: int64
#
# Column:  sick
#
# f    2530
# t     113
# Name: sick, dtype: int64
#
# Column:  pregnant
#
# f    2602
# t      41
# Name: pregnant, dtype: int64
#
# Column:  thyroid surgery
#
# f    2610
# t      33
# Name: thyroid surgery, dtype: int64
#
# Column:  I131 treatment
#
# f    2603
# t      40
# Name: I131 treatment, dtype: int64
#
# Column:  query hypothyroid
#
# f    2497
# t     146
# Name: query hypothyroid, dtype: int64
#
# Column:  query hyperthyroid
#
# f    2480
# t     163
# Name: query hyperthyroid, dtype: int64
#
# Column:  lithium
#
# f    2629
# t      14
# Name: lithium, dtype: int64
#
# Column:  goitre
#
# ...

# %%
unwanted_columns    = ['TSH measured','T3 measured','TT4 measured','T4U measured','FTI measured','TBG measured','hypopituitary']
df.drop(columns     = unwanted_columns, inplace = True )
categorical_columns = ['sex', 'on thyroxine', 'query on thyroxine', 'on antithyroid medication', 'sick', \
                        'pregnant', 'thyroid surgery', 'I131 treatment', 'query hypothyroid', 'query hyperthyroid', \
                        'lithium', 'goitre', 'tumor', 'psych', 'referral source', 'binaryClass']

# %%
print(df.shape)
# Out:
# (2643, 22)

# %%
print(df.describe())
print(df.describe(exclude = [np.number]))
# Out:
#                age          TSH           T3          TT4          T4U  \
# count  2643.000000  2643.000000  2643.000000  2643.000000  2643.000000
# mean     53.081725     5.035978     2.001150   107.858683     0.995650
# std      20.367966    23.974851     0.823814    35.460437     0.196445
# min       1.000000     0.005000     0.050000     2.000000     0.250000
# 25%      37.000000     0.500000     1.500000    88.000000     0.870000
# 50%      55.000000     1.300000     2.000000   103.000000     0.980000
# 75%      69.000000     2.600000     2.300000   124.000000     1.090000
# max     455.000000   530.000000    10.600000   430.000000     2.120000
#
#                FTI
# count  2643.000000
# mean    109.435906
# std      32.472156
# min       2.000000
# 25%      93.000000
# 50%     107.000000
# 75%     124.000000
# max     395.000000
#          sex on thyroxine query on thyroxine on antithyroid medication  sick  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.boxplot(data = df, orient = "h", palette = "Set1")
plt.show()

# %%
def outlier_detect(df):
    for i in df.describe().columns:

        Q1=df.describe().at['25%',i]
        Q3=df.describe().at['75%',i]
        IQR=Q3 - Q1
        LTV=Q1 - 1.5 * IQR
        UTV=Q3 + 1.5 * IQR
        x=np.array(df[i])
        p=[]
        for j in x:
            if j < LTV or j>UTV:
               p.append(j)
        print('\n Outliers for Column : ', i, ' Outliers count ', len(p))
        print(p)

# %%
x  =  df[numeric_columns]
outlier_detect(x)
# Out:
#  Outliers for Column :  age  Outliers count  1
# [455]
#
#  Outliers for Column :  TSH  Outliers count  278
# ...

# %%
def draw_barplot(df, X, xlab, title, Y):
    
    x       =   df[X]
    y       =   df[Y]
    ct = pd.crosstab(df[X], y)
    print("\n Cross tab with count\n")
    print(ct)

    ### Cross tab with row percentages
    print("\n Cross tab with row % \n")
    ct1 = pd.crosstab(df[X], Y, normalize = 'index').round(4)*100
    print(ct1)

    # now stack and reset
    stacked = ct.stack().reset_index().rename(columns={0:'value'})
    print(list(stacked))
    ##plot grouped bar chart
    ax = sns.barplot(x = stacked[X], y = stacked.value, hue = stacked[Y])
    ax.set_title(title)    
    plt.show()

# %%
def draw_boxplot(df, X, xlab, title, Y):
    import seaborn           as sns
    import matplotlib.pyplot as plt
    
    x       =   df[X]
    print("\n Summary statistics for  " + xlab + "\n")
    print(df[X].groupby(df[Y]).describe().T)

    sns.set_style("whitegrid")
    ax = sns.boxplot(x = df[X] ,y =  df[Y])
    ax.set_title(title)
    plt.show()

# %%
def draw_hist(df, X, title):
    import seaborn           as sns
    import matplotlib.pyplot as plt
    
    sns.distplot(df[X]).set_title(title);
    plt.show();

# %%
for i in range(len(numeric_columns)):
    feature_X  = numeric_columns[i]
    target_Y   = 'binaryClass'
    title      = "Histogram for the variable " + feature_X 
    draw_hist(df, feature_X, title)
    title      = "Boxplot for the variable " + feature_X 
##    
    draw_boxplot(df, feature_X, feature_X, title, target_Y)
# Out:
#  Summary statistics for  age
#
# binaryClass           N            P
# count        216.000000  2427.000000
# mean          53.125000    53.077874
# std           16.788926    20.659393
# min            7.000000     1.000000
# 25%           40.000000    37.000000
# 50%           55.000000    55.000000
# 75%           65.500000    69.000000
# max           85.000000   455.000000
#  Summary statistics for  TSH
#
# binaryClass           N            P
# count        216.000000  2427.000000
# mean          41.174074     1.819732
# std           73.313813     4.796108
# min            4.600000     0.005000
# 25%            8.300000     0.400000
# 50%           13.000000     1.200000
# 75%           38.500000     2.200000
# max          530.000000   145.000000
#  Summary statistics for  T3
#
# binaryClass           N            P
# count        216.000000  2427.000000
# mean           1.463426     2.049007
# std            0.764750     0.811929
# min            0.200000     0.050000
# ...

# %%
categorical_columns = ['sex', 'on thyroxine', 'query on thyroxine', 'on antithyroid medication', 'sick', \
                        'pregnant', 'thyroid surgery', 'I131 treatment', 'query hypothyroid', 'query hyperthyroid', \
                        'lithium', 'goitre', 'tumor', 'psych', 'referral source']
for name in categorical_columns:
    X1         = name
    target_Y   = 'binaryClass'
    xlab       = 'Sex'
    title      = "Barplot for the variable " + X1 
    draw_barplot(df, X1, xlab, title, target_Y)
# Out:
#  Cross tab with count
#
# binaryClass    N     P
# sex
# F            167  1597
# M             49   830
#
#  Cross tab with row %
#
# col_0  binaryClass
# sex
# F            100.0
# M            100.0
# ['sex', 'binaryClass', 'value']
#  Cross tab with count
#
# binaryClass     N     P
# on thyroxine
# f             209  2168
# t               7   259
#
#  Cross tab with row %
#
# col_0         binaryClass
# on thyroxine
# f                   100.0
# t                   100.0
# ['on thyroxine', 'binaryClass', 'value']
#  Cross tab with count
#
# binaryClass           N     P
# query on thyroxine
# f                   214  2405
# t                     2    22
#
#  Cross tab with row %
#
# col_0               binaryClass
# query on thyroxine
# f                         100.0
# t                         100.0
# ['query on thyroxine', 'binaryClass', 'value']
#  Cross tab with count
#
# binaryClass                  N     P
# on antithyroid medication
# ...
